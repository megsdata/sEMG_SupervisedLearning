# %% [markdown]
# <a href="https://colab.research.google.com/github/megsdata/sEMG_SupervisedLearning/blob/main/23Jul09_Deep_Learning_LSTM_regularized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pathlib
import os
import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2
import weightwatcher as ww
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)
np.set_printoptions(precision=4)
print(tf.version.VERSION)
# Out:
# 2.12.0

# %%
# !pip install WeightWatcher
#!pip install pyyaml
#!pip install h5py
# Out:
# Collecting WeightWatcher
#   Downloading weightwatcher-0.7.1.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (3.7.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (0.1.6)
# Collecting powerlaw (from WeightWatcher)
#   Downloading powerlaw-1.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from WeightWatcher) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WeightWatcher) (2.8.2)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.10/dist-packages (from matplotlib-inline->WeightWatcher) (5.7.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->WeightWatcher) (2022.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from powerlaw->WeightWatcher) (1.10.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.10/dist-packages (from powerlaw->WeightWatcher) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->WeightWatcher) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->WeightWatcher) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->WeightWatcher) (1.16.0)
# Installing collected packages: powerlaw, WeightWatcher
# Successfully installed WeightWatcher-0.7.1.5 powerlaw-1.5

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(ww.__name__)
logger.setLevel(logging.INFO)
checkpoint_path = "logs/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
from google.colab import drive
drive.mount('/MSC_THESIS/')
# %cd /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/23Jul09_Envelope_DL_Data
import pathlib
all_files =  sorted(str(p) for p in pathlib.Path('/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/23Jul09_Envelope_DL_Data/').glob("*.csv"))
#print(all_files)
df = pd.read_csv("/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/23Jul09_Envelope_DL_Data/_11_MATRIX.csv")
for i in range(len(all_files)-1):
  temp = pd.read_csv(all_files[i])
  df = pd.concat([df, temp], axis=0)
  #print(len(df.index))
df['ContractionDuration'] = df['Contraction End Time (s)'] - df['Contraction Start Time(s)']
# Out:
# Mounted at /MSC_THESIS/
# /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/23Jul09_Envelope_DL_Data

# %%
df.head()
# Out:
#    Participant ID  Trial ID  Trial Type  Pulse Width  \
# 0               1        11           1     2.677351
# 1               1        11           1     2.677351
# 2               1        11           1     2.677351
# 3               1        11           1     2.677351
# 4               1        11           1     2.677351
#
#    Contraction Start Time(s)  Contraction End Time (s)  ContractionNo  \
# 0                   6.506103                  9.183454              1
# 1                   6.506103                  9.183454              1
# 2                   6.506103                  9.183454              1
# 3                   6.506103                  9.183454              1
# 4                   6.506103                  9.183454              1
#
#    Pain Label  Sex  Age  ...  Weight  Previous Injury  Fibula Length  \
# 0           1    1   23  ...    50.0                0           35.0
# 1           1    1   23  ...    50.0                0           35.0
# 2           1    1   23  ...    50.0                0           35.0
# 3           1    1   23  ...    50.0                0           35.0
# 4           1    1   23  ...    50.0                0           35.0
#
#    Shank Girth  Time(s)    EMG(mv)     MMG_x     MMG_y     MMG_z  \
# 0         35.0   6.5062  95.524229  1.591994  1.301494  1.546334
# 1         35.0   6.5064  95.876228  1.596378  1.301486  1.546180
# 2         35.0   6.5066  96.267965  1.600714  1.301478  1.546035
# 3         35.0   6.5068  96.670317  1.604998  1.301471  1.545901
# 4         35.0   6.5070  97.063615  1.609228  1.301467  1.545781
#
#    ContractionDuration
# 0             2.677351
# 1             2.677351
# 2             2.677351
# 3             2.677351
# 4             2.677351
#
# [5 rows x 21 columns]

# %% [markdown]
# Helper Functions

# %%
def data_prep(my_state):
  #select features
  X = df[['Trial Type', 'ContractionDuration', 'Pulse Width', \
          'Contraction Start Time(s)', 'Contraction End Time (s)', 'ContractionNo', \
          'Sex', 'Age', 'Height', 'Weight', 'Previous Injury', 'Fibula Length', 'Shank Girth', \
          'Time(s)', 'EMG(mv)', 'MMG_x', 'MMG_y', 'MMG_z', 'ContractionDuration'
          ]]
  y = df['Pain Label']
  #create data split
  from sklearn.model_selection import train_test_split
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=my_state)
  X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=my_state)
  print("Number of samples in the training set: ", len(X_train))
  print("Number of samples in the test set: ", len(X_test))
  print("Number of samples in the validation set: ", len(X_val))
  #scale the data
  from sklearn.preprocessing import StandardScaler
  scaler = StandardScaler()
  X_train_scaled = scaler.fit_transform(X_train)
  X_test_scaled = scaler.transform(X_test)
  X_val_scaled = scaler.transform(X_val)
  return X_train_scaled, X_test_scaled, X_val_scaled, y_train, y_test, y_val

# %%
def create_CNN_model(my_state, num_feat):
  tf.random.set_seed(my_state)
  model = tf.keras.Sequential([
      tf.keras.layers.Conv1D(100, num_feat, activation='relu', name="convLayer", input_shape=(num_feat, 1)),
      tf.keras.layers.Dense(1024, activation='relu', name="relu1Layer"),
      #tf.keras.layers.Conv1D(100, num_feat, activation='relu', name="2ndconvLayer", input_shape=(None, 1, 100000)),
      tf.keras.layers.Dense(256, activation='relu', name="relu2Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu3Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu4Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu5Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu6Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu7Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu8Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu9Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu10Layer"),
      tf.keras.layers.Dense(1, activation='sigmoid', name="sigmoidLayer")
      #tf.keras.layers.Dense(1, activation='relu', name="sigmoidLayer")
  ])

  model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.BinaryCrossentropy(name='binary cross entropy'),
        tf.keras.metrics.BinaryIoU(name='binary IoU')
    ]
  )
  return model

def create_LSTM_model(my_state, num_feat):
  tf.random.set_seed(my_state)
  model = tf.keras.Sequential([
      #tf.keras.layers.LSTM(128, input_shape=(num_feat, 1)),
      tf.keras.layers.LSTM(256, input_shape=(num_feat, 1)),
      tf.keras.layers.Dense(128, activation='relu', name="relu1Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu2Layer"),
      tf.keras.layers.Dense(256, activation='relu', name="relu3Layer"),
      tf.keras.layers.Dense(1, activation='sigmoid', name="sigmoidLayer")
  ])
  model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.BinaryCrossentropy(name='binary cross entropy'),
        tf.keras.metrics.BinaryIoU(name='binary IoU')
    ]
  )
  return model

def create_regularized_LSTM_model(my_state, factor, rate, num_feat):
  tf.random.set_seed(my_state)
  model = tf.keras.Sequential([
      #Dropout(rate),
      tf.keras.layers.LSTM(256, input_shape=(num_feat, 1)),
      #Dropout(rate),
      #tf.keras.layers.LSTM(128, input_shape=(None, 1, 256)),
      Dropout(rate),
      tf.keras.layers.Dense(128, kernel_regularizer=l2(factor), activation='relu', name="relu1Layer"),
      Dropout(rate),
      tf.keras.layers.Dense(256, kernel_regularizer=l2(factor), activation='relu', name="relu2Layer"),
      Dropout(rate),
      tf.keras.layers.Dense(256, kernel_regularizer=l2(factor), activation='relu', name="relu3Layer"),
      Dropout(rate),
      tf.keras.layers.Dense(256, kernel_regularizer=l2(factor), activation='relu', name="relu4Layer"),
      tf.keras.layers.Dense(1, activation='sigmoid', name="sigmoidLayer")
      #tf.keras.layers.Dense(1, activation='relu', name="reluLayer")
  ])

  model.compile(
      loss=tf.keras.losses.binary_crossentropy,
      optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
      metrics=[
          tf.keras.metrics.BinaryAccuracy(name='accuracy'),
          tf.keras.metrics.Precision(name='precision'),
          tf.keras.metrics.Recall(name='recall'),
          tf.keras.metrics.BinaryCrossentropy(name='binary cross entropy'),
          tf.keras.metrics.BinaryIoU(name='binary IoU')
      ]
  )
  return model

def train_model(X_train_scaled, y_train, num_epochs):
  tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=checkpoint_dir, histogram_freq=1)
  print("Training the neural network.. ")
  history = model.fit(X_train_scaled, y_train, batch_size=32, epochs=num_epochs, callbacks=[cp_callback])
  model.summary()
  return history

def visualize_performance(num_epochs, history):
  import matplotlib.pyplot as plt
  from matplotlib import rcParams
  rcParams['figure.figsize'] = (18, 8)
  rcParams['axes.spines.top'] = False
  rcParams['axes.spines.right'] = False
  plt.plot(
      np.arange(1, num_epochs+1),
      history.history['loss'], label='Loss'
  )
  plt.plot(
      np.arange(1, num_epochs+1),
      history.history['accuracy'], label='Accuracy'
  )
  plt.plot(
      np.arange(1, num_epochs+1),
      history.history['precision'], label='Precision'
  )
  plt.plot(
      np.arange(1, num_epochs+1),
      history.history['recall'], label='Recall'
  )
  plt.title('Evaluation metrics', size=20)
  plt.xlabel('Epoch', size=14)
  plt.legend();

def evaluate_performance(model, X_test_scaled, y_test):
  predictions = model.predict(X_test_scaled)
  prediction_classes = [
      1 if prob > 0.5 else 0 for prob in np.ravel(predictions)
  ]
  prediction_classes = [
      1 if prob > 0.5 else 0 for prob in np.ravel(predictions)
  ]
  from sklearn.metrics import accuracy_score, precision_score, recall_score

  print(f'Accuracy: {accuracy_score(y_test, prediction_classes):.4f}')
  print(f'Precision: {precision_score(y_test, prediction_classes):.4f}')
  print(f'Recall: {recall_score(y_test, prediction_classes):.4f}')

# %%
#choose a random state
# %load_ext tensorboard
checkpoint_dir = "/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
my_state = 16
num_epochs = 1
X_train_scaled, X_test_scaled, X_val_scaled, y_train, y_test, y_val = data_prep(my_state)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Number of samples in the training set:  3240141
# Number of samples in the test set:  1012545
# Number of samples in the validation set:  810036

# %%
model = create_CNN_model(my_state, 19) #model creation and compilation
history = train_model(X_val_scaled, y_val, num_epochs) #validation
visualize_performance(num_epochs, history)
evaluate_performance(model, X_test_scaled, y_test)
model.summary()
# Out:
# Training the neural network..
# 25307/25314 [============================>.] - ETA: 0s - loss: 4.5391 - accuracy: 0.7023 - precision: 0.7024 - recall: 1.0000 - binary cross entropy: 4.5391 - binary IoU: 0.3512
# Epoch 1: saving model to logs/cp.ckpt
# 25314/25314 [==============================] - 183s 7ms/step - loss: 4.5390 - accuracy: 0.7024 - precision: 0.7024 - recall: 1.0000 - binary cross entropy: 4.5390 - binary IoU: 0.3512
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relu1Layer (Dense)          (None, 1024)              20480
#
#  relu2Layer (Dense)          (None, 256)               262400
#
#  relu3Layer (Dense)          (None, 256)               65792
#
#  relu4Layer (Dense)          (None, 256)               65792
#
#  relu5Layer (Dense)          (None, 256)               65792
#
#  relu6Layer (Dense)          (None, 256)               65792
#
#  relu7Layer (Dense)          (None, 256)               65792
#
#  relu8Layer (Dense)          (None, 256)               65792
#
#  relu9Layer (Dense)          (None, 256)               65792
#
#  relu10Layer (Dense)         (None, 256)               65792
#
#  sigmoidLayer (Dense)        (None, 1)                 257
#
# =================================================================
# Total params: 809,473
# Trainable params: 809,473
# Non-trainable params: 0
# _________________________________________________________________
# 31643/31643 [==============================] - 49s 2ms/step
# Accuracy: 0.7032
# Precision: 0.7032
# Recall: 1.0000
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  relu1Layer (Dense)          (None, 1024)              20480
#
#  relu2Layer (Dense)          (None, 256)               262400
#
#  relu3Layer (Dense)          (None, 256)               65792
#
#  relu4Layer (Dense)          (None, 256)               65792
#
#  relu5Layer (Dense)          (None, 256)               65792
#
#  relu6Layer (Dense)          (None, 256)               65792
#
#  relu7Layer (Dense)          (None, 256)               65792
#
#  relu8Layer (Dense)          (None, 256)               65792
#
#  relu9Layer (Dense)          (None, 256)               65792
#
#  relu10Layer (Dense)         (None, 256)               65792
#
#  sigmoidLayer (Dense)        (None, 1)                 257
#
# =================================================================
# Total params: 809,473
# Trainable params: 809,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_state = 18
num_epochs = 10
# Create a callback that saves the model's weights
checkpoint_path = "/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
model = create_LSTM_model(my_state, 19) #model creation and compilation
model.save_weights(checkpoint_path.format(epoch=0))
print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f68ec58c880>

# %%
history = train_model(X_train_scaled, y_train, num_epochs)
visualize_performance(num_epochs, history)
evaluate_performance(model, X_test_scaled, y_test)
os.listdir(checkpoint_dir)
# Out:
# Training the neural network..
# Epoch 1/10
# 101253/101255 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9791 - precision: 0.9859 - recall: 0.9844 - binary cross entropy: 0.0578 - binary IoU: 0.9515
# Epoch 1: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0001.ckpt
# 101255/101255 [==============================] - 652s 6ms/step - loss: 0.0578 - accuracy: 0.9791 - precision: 0.9859 - recall: 0.9844 - binary cross entropy: 0.0578 - binary IoU: 0.9515
# Epoch 2/10
# 101252/101255 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9519 - precision: 0.9683 - recall: 0.9630 - binary cross entropy: 0.1212 - binary IoU: 0.8924
# Epoch 2: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0002.ckpt
# 101255/101255 [==============================] - 635s 6ms/step - loss: 0.1213 - accuracy: 0.9519 - precision: 0.9683 - recall: 0.9630 - binary cross entropy: 0.1213 - binary IoU: 0.8924
# Epoch 3/10
# 101252/101255 [============================>.] - ETA: 0s - loss: 0.5973 - accuracy: 0.7069 - precision: 0.7131 - recall: 0.9753 - binary cross entropy: 0.5973 - binary IoU: 0.3844
# Epoch 3: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0003.ckpt
# 101255/101255 [==============================] - 634s 6ms/step - loss: 0.5973 - accuracy: 0.7069 - precision: 0.7131 - recall: 0.9753 - binary cross entropy: 0.5973 - binary IoU: 0.3844
# Epoch 4/10
# 101249/101255 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 4: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0004.ckpt
# 101255/101255 [==============================] - 641s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 5/10
# 101251/101255 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 5: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0005.ckpt
# 101255/101255 [==============================] - 644s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 6/10
# 101255/101255 [==============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 6: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0006.ckpt
# 101255/101255 [==============================] - 640s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 7/10
# 101255/101255 [==============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 7: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0007.ckpt
# 101255/101255 [==============================] - 645s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 8/10
# 101253/101255 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 8: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0008.ckpt
# 101255/101255 [==============================] - 640s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 9/10
# 101250/101255 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 9: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0009.ckpt
# 101255/101255 [==============================] - 640s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 10/10
# 101250/101255 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Epoch 10: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0010.ckpt
# 101255/101255 [==============================] - 645s 6ms/step - loss: 0.6087 - accuracy: 0.7027 - precision: 0.7027 - recall: 1.0000 - binary cross entropy: 0.6087 - binary IoU: 0.3513
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 256)               264192
#
#  relu1Layer (Dense)          (None, 128)               32896
#
#  relu2Layer (Dense)          (None, 256)               33024
#
#  relu3Layer (Dense)          (None, 256)               65792
#
#  sigmoidLayer (Dense)        (None, 1)                 257
#
# =================================================================
# Total params: 396,161
# Trainable params: 396,161
# Non-trainable params: 0
# _________________________________________________________________
# 31643/31643 [==============================] - 62s 2ms/step
# Accuracy: 0.7028
# Precision: 0.7028
# Recall: 1.0000
# ['cp-0000.ckpt.data-00000-of-00001',
#  'cp-0000.ckpt.index',
#  'checkpoint',
#  'cp-0001.ckpt.data-00000-of-00001',
#  'cp-0001.ckpt.index',
#  'cp-0002.ckpt.data-00000-of-00001',
#  'cp-0002.ckpt.index',
#  'cp-0003.ckpt.data-00000-of-00001',
#  'cp-0003.ckpt.index',
#  'cp-0004.ckpt.data-00000-of-00001',
#  'cp-0004.ckpt.index',
#  'cp-0005.ckpt.data-00000-of-00001',
#  'cp-0005.ckpt.index',
#  'cp-0006.ckpt.data-00000-of-00001',
#  'cp-0006.ckpt.index',
#  'cp-0007.ckpt.data-00000-of-00001',
#  'cp-0007.ckpt.index',
#  'cp-0008.ckpt.data-00000-of-00001',
#  'cp-0008.ckpt.index',
#  'cp-0009.ckpt.data-00000-of-00001',
#  'cp-0009.ckpt.index',
#  'cp-0010.ckpt.data-00000-of-00001',
#  'cp-0010.ckpt.index']

# %%
# Save the entire model as a SavedModel.
# !mkdir -p saved_model
model.save('saved_model/LSTM')

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest

# %%
y_pred= model.predict(X_test_scaled)
# Out:
# 31643/31643 [==============================] - 59s 2ms/step
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[300935,      0],
#        [331656, 379954]], dtype=int32)>

# %%
import seaborn as sns
confusion_mtx = tf.math.confusion_matrix(
    y_test,
    y_pred,
    num_classes=2,
    weights=None,
    dtype=tf.dtypes.int32,
    name=None
)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b3c8a058ff98> in <cell line: 11>()
#      10 plt.figure(figsize=(10, 8))
#      11 sns.heatmap(confusion_mtx,
# ---> 12             xticklabels=label_names,
#      13             yticklabels=label_names,
#      14             annot=True, fmt='g')
#
# NameError: name 'label_names' is not defined

# %%
my_state = 20
num_epochs = 100
X_train_scaled, X_test_scaled, X_val_scaled, y_train, y_test, y_val = data_prep(my_state)
# Create a callback that saves the model's weights
checkpoint_path = "/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
#model = create_LSTM_model(my_state, 19) #model creation and compilation
# Create a new model instance


# Restore the weights
#model.load_weights('/MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09/cp-0010.ckpt')
# Out:
# Number of samples in the training set:  3240141
# Number of samples in the test set:  1012545
# Number of samples in the validation set:  810036

# %%
#evaluate_performance(model, X_test_scaled, y_test)
# Out:
# 31643/31643 [==============================] - 65s 2ms/step
# Accuracy: 0.7032
# Precision: 0.7032
# Recall: 1.0000

# %%
model.save_weights(checkpoint_path.format(epoch=0))
print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f288e7b88b0>

# %%
model = create_regularized_LSTM_model(my_state, 1e-5, 0.3, 19) #model creation and compilation
#model = create_CNN_model(my_state, 4) #model creation and compilation
#history = train_model(X_train_scaled, y_train, num_epochs) #training
history = train_model(X_val_scaled, y_val, num_epochs) #validation
visualize_performance(num_epochs, history)
evaluate_performance(model, X_test_scaled, y_test)
# Out:
# Training the neural network..
# Epoch 1/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.2557 - accuracy: 0.8932 - precision: 0.9160 - recall: 0.9336 - binary cross entropy: 0.2436 - binary IoU: 0.7748
# Epoch 1: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0001.ckpt
# 25314/25314 [==============================] - 177s 7ms/step - loss: 0.2558 - accuracy: 0.8932 - precision: 0.9160 - recall: 0.9336 - binary cross entropy: 0.2436 - binary IoU: 0.7748
# Epoch 2/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.4463 - accuracy: 0.8108 - precision: 0.8795 - recall: 0.8468 - binary cross entropy: 0.4401 - binary IoU: 0.6458
# Epoch 2: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0002.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.4463 - accuracy: 0.8108 - precision: 0.8795 - recall: 0.8468 - binary cross entropy: 0.4401 - binary IoU: 0.6458
# Epoch 3/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8249 - precision: 0.8811 - recall: 0.8679 - binary cross entropy: 0.4210 - binary IoU: 0.6640
# Epoch 3: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0003.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.4286 - accuracy: 0.8249 - precision: 0.8811 - recall: 0.8679 - binary cross entropy: 0.4210 - binary IoU: 0.6640
# Epoch 4/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.4018 - accuracy: 0.8529 - precision: 0.8924 - recall: 0.8991 - binary cross entropy: 0.3947 - binary IoU: 0.7058
# Epoch 4: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0004.ckpt
# 25314/25314 [==============================] - 176s 7ms/step - loss: 0.4018 - accuracy: 0.8529 - precision: 0.8924 - recall: 0.8991 - binary cross entropy: 0.3947 - binary IoU: 0.7058
# Epoch 5/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3790 - accuracy: 0.8693 - precision: 0.8958 - recall: 0.9212 - binary cross entropy: 0.3726 - binary IoU: 0.7308
# Epoch 5: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0005.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3790 - accuracy: 0.8693 - precision: 0.8958 - recall: 0.9212 - binary cross entropy: 0.3726 - binary IoU: 0.7308
# Epoch 6/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3673 - accuracy: 0.8731 - precision: 0.8985 - recall: 0.9238 - binary cross entropy: 0.3616 - binary IoU: 0.7374
# Epoch 6: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0006.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3673 - accuracy: 0.8731 - precision: 0.8985 - recall: 0.9238 - binary cross entropy: 0.3616 - binary IoU: 0.7374
# Epoch 7/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.4038 - accuracy: 0.8508 - precision: 0.8912 - recall: 0.8972 - binary cross entropy: 0.3970 - binary IoU: 0.7024
# Epoch 7: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0007.ckpt
# 25314/25314 [==============================] - 175s 7ms/step - loss: 0.4038 - accuracy: 0.8508 - precision: 0.8912 - recall: 0.8972 - binary cross entropy: 0.3970 - binary IoU: 0.7024
# Epoch 8/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.4134 - accuracy: 0.8467 - precision: 0.8863 - recall: 0.8969 - binary cross entropy: 0.4055 - binary IoU: 0.6949
# Epoch 8: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0008.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.4134 - accuracy: 0.8467 - precision: 0.8863 - recall: 0.8969 - binary cross entropy: 0.4055 - binary IoU: 0.6949
# Epoch 9/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3749 - accuracy: 0.8749 - precision: 0.8970 - recall: 0.9287 - binary cross entropy: 0.3674 - binary IoU: 0.7395
# Epoch 9: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0009.ckpt
# 25314/25314 [==============================] - 175s 7ms/step - loss: 0.3749 - accuracy: 0.8749 - precision: 0.8970 - recall: 0.9287 - binary cross entropy: 0.3674 - binary IoU: 0.7395
# Epoch 10/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3557 - accuracy: 0.8845 - precision: 0.9011 - recall: 0.9386 - binary cross entropy: 0.3492 - binary IoU: 0.7558
# Epoch 10: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0010.ckpt
# 25314/25314 [==============================] - 175s 7ms/step - loss: 0.3557 - accuracy: 0.8845 - precision: 0.9011 - recall: 0.9386 - binary cross entropy: 0.3492 - binary IoU: 0.7558
# Epoch 11/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8755 - precision: 0.9004 - recall: 0.9251 - binary cross entropy: 0.3630 - binary IoU: 0.7417
# Epoch 11: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0011.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3690 - accuracy: 0.8755 - precision: 0.9004 - recall: 0.9251 - binary cross entropy: 0.3630 - binary IoU: 0.7417
# Epoch 12/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3699 - accuracy: 0.8770 - precision: 0.8946 - recall: 0.9352 - binary cross entropy: 0.3632 - binary IoU: 0.7418
# Epoch 12: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0012.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3700 - accuracy: 0.8770 - precision: 0.8946 - recall: 0.9352 - binary cross entropy: 0.3633 - binary IoU: 0.7418
# Epoch 13/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3767 - accuracy: 0.8722 - precision: 0.8977 - recall: 0.9234 - binary cross entropy: 0.3692 - binary IoU: 0.7358
# Epoch 13: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0013.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3767 - accuracy: 0.8722 - precision: 0.8977 - recall: 0.9234 - binary cross entropy: 0.3693 - binary IoU: 0.7358
# Epoch 14/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8701 - precision: 0.8959 - recall: 0.9222 - binary cross entropy: 0.3712 - binary IoU: 0.7319
# Epoch 14: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0014.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3784 - accuracy: 0.8701 - precision: 0.8959 - recall: 0.9222 - binary cross entropy: 0.3712 - binary IoU: 0.7319
# Epoch 15/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3822 - accuracy: 0.8685 - precision: 0.8924 - recall: 0.9243 - binary cross entropy: 0.3749 - binary IoU: 0.7282
# Epoch 15: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0015.ckpt
# 25314/25314 [==============================] - 171s 7ms/step - loss: 0.3822 - accuracy: 0.8685 - precision: 0.8924 - recall: 0.9243 - binary cross entropy: 0.3749 - binary IoU: 0.7282
# Epoch 16/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8751 - precision: 0.9021 - recall: 0.9223 - binary cross entropy: 0.3648 - binary IoU: 0.7417
# Epoch 16: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0016.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.3719 - accuracy: 0.8751 - precision: 0.9021 - recall: 0.9223 - binary cross entropy: 0.3648 - binary IoU: 0.7417
# Epoch 17/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8550 - precision: 0.8891 - recall: 0.9069 - binary cross entropy: 0.3952 - binary IoU: 0.7075
# Epoch 17: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0017.ckpt
# 25314/25314 [==============================] - 171s 7ms/step - loss: 0.4035 - accuracy: 0.8551 - precision: 0.8891 - recall: 0.9069 - binary cross entropy: 0.3952 - binary IoU: 0.7075
# Epoch 18/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3741 - accuracy: 0.8753 - precision: 0.8972 - recall: 0.9289 - binary cross entropy: 0.3658 - binary IoU: 0.7402
# Epoch 18: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0018.ckpt
# 25314/25314 [==============================] - 170s 7ms/step - loss: 0.3741 - accuracy: 0.8752 - precision: 0.8972 - recall: 0.9289 - binary cross entropy: 0.3658 - binary IoU: 0.7401
# Epoch 19/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8570 - precision: 0.8871 - recall: 0.9127 - binary cross entropy: 0.3922 - binary IoU: 0.7095
# Epoch 19: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0019.ckpt
# 25314/25314 [==============================] - 170s 7ms/step - loss: 0.3998 - accuracy: 0.8570 - precision: 0.8871 - recall: 0.9127 - binary cross entropy: 0.3922 - binary IoU: 0.7095
# Epoch 20/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8596 - precision: 0.8875 - recall: 0.9163 - binary cross entropy: 0.3913 - binary IoU: 0.7133
# Epoch 20: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0020.ckpt
# 25314/25314 [==============================] - 170s 7ms/step - loss: 0.3998 - accuracy: 0.8596 - precision: 0.8875 - recall: 0.9163 - binary cross entropy: 0.3913 - binary IoU: 0.7133
# Epoch 21/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8750 - precision: 0.8955 - recall: 0.9308 - binary cross entropy: 0.3675 - binary IoU: 0.7392
# Epoch 21: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0021.ckpt
# 25314/25314 [==============================] - 171s 7ms/step - loss: 0.3741 - accuracy: 0.8750 - precision: 0.8955 - recall: 0.9308 - binary cross entropy: 0.3675 - binary IoU: 0.7392
# Epoch 22/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8775 - precision: 0.8988 - recall: 0.9303 - binary cross entropy: 0.3622 - binary IoU: 0.7441
# Epoch 22: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0022.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.3686 - accuracy: 0.8775 - precision: 0.8988 - recall: 0.9303 - binary cross entropy: 0.3622 - binary IoU: 0.7441
# Epoch 23/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3697 - accuracy: 0.8776 - precision: 0.8928 - recall: 0.9384 - binary cross entropy: 0.3631 - binary IoU: 0.7420
# Epoch 23: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0023.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.3697 - accuracy: 0.8776 - precision: 0.8928 - recall: 0.9384 - binary cross entropy: 0.3632 - binary IoU: 0.7420
# Epoch 24/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3531 - accuracy: 0.8861 - precision: 0.9033 - recall: 0.9384 - binary cross entropy: 0.3481 - binary IoU: 0.7592
# Epoch 24: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0024.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3531 - accuracy: 0.8861 - precision: 0.9033 - recall: 0.9384 - binary cross entropy: 0.3481 - binary IoU: 0.7592
# Epoch 25/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3549 - accuracy: 0.8857 - precision: 0.9012 - recall: 0.9405 - binary cross entropy: 0.3498 - binary IoU: 0.7578
# Epoch 25: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0025.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3549 - accuracy: 0.8857 - precision: 0.9012 - recall: 0.9405 - binary cross entropy: 0.3498 - binary IoU: 0.7578
# Epoch 26/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3699 - accuracy: 0.8773 - precision: 0.8944 - recall: 0.9358 - binary cross entropy: 0.3638 - binary IoU: 0.7421
# Epoch 26: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0026.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3699 - accuracy: 0.8773 - precision: 0.8944 - recall: 0.9358 - binary cross entropy: 0.3638 - binary IoU: 0.7421
# Epoch 27/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8833 - precision: 0.8981 - recall: 0.9407 - binary cross entropy: 0.3547 - binary IoU: 0.7528
# Epoch 27: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0027.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3606 - accuracy: 0.8833 - precision: 0.8981 - recall: 0.9407 - binary cross entropy: 0.3547 - binary IoU: 0.7528
# Epoch 28/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3798 - accuracy: 0.8721 - precision: 0.8901 - recall: 0.9332 - binary cross entropy: 0.3732 - binary IoU: 0.7326
# Epoch 28: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0028.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3798 - accuracy: 0.8721 - precision: 0.8901 - recall: 0.9332 - binary cross entropy: 0.3732 - binary IoU: 0.7326
# Epoch 29/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3617 - accuracy: 0.8820 - precision: 0.8987 - recall: 0.9377 - binary cross entropy: 0.3555 - binary IoU: 0.7511
# Epoch 29: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0029.ckpt
# 25314/25314 [==============================] - 171s 7ms/step - loss: 0.3617 - accuracy: 0.8820 - precision: 0.8987 - recall: 0.9377 - binary cross entropy: 0.3555 - binary IoU: 0.7511
# Epoch 30/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3494 - accuracy: 0.8894 - precision: 0.9011 - recall: 0.9465 - binary cross entropy: 0.3424 - binary IoU: 0.7635
# Epoch 30: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0030.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.3494 - accuracy: 0.8894 - precision: 0.9011 - recall: 0.9465 - binary cross entropy: 0.3424 - binary IoU: 0.7635
# Epoch 31/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8861 - precision: 0.9015 - recall: 0.9407 - binary cross entropy: 0.3482 - binary IoU: 0.7586
# Epoch 31: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0031.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3550 - accuracy: 0.8861 - precision: 0.9015 - recall: 0.9407 - binary cross entropy: 0.3482 - binary IoU: 0.7586
# Epoch 32/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3566 - accuracy: 0.8853 - precision: 0.8965 - recall: 0.9459 - binary cross entropy: 0.3502 - binary IoU: 0.7553
# Epoch 32: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0032.ckpt
# 25314/25314 [==============================] - 187s 7ms/step - loss: 0.3566 - accuracy: 0.8853 - precision: 0.8965 - recall: 0.9459 - binary cross entropy: 0.3502 - binary IoU: 0.7553
# Epoch 33/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8903 - precision: 0.9041 - recall: 0.9440 - binary cross entropy: 0.3401 - binary IoU: 0.7660
# Epoch 33: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0033.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3470 - accuracy: 0.8903 - precision: 0.9041 - recall: 0.9440 - binary cross entropy: 0.3401 - binary IoU: 0.7660
# Epoch 34/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.8982 - precision: 0.9071 - recall: 0.9527 - binary cross entropy: 0.3247 - binary IoU: 0.7800
# Epoch 34: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0034.ckpt
# 25314/25314 [==============================] - 175s 7ms/step - loss: 0.3311 - accuracy: 0.8982 - precision: 0.9071 - recall: 0.9527 - binary cross entropy: 0.3247 - binary IoU: 0.7800
# Epoch 35/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3153 - accuracy: 0.9057 - precision: 0.9040 - recall: 0.9688 - binary cross entropy: 0.3094 - binary IoU: 0.7916
# Epoch 35: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0035.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3153 - accuracy: 0.9057 - precision: 0.9040 - recall: 0.9688 - binary cross entropy: 0.3095 - binary IoU: 0.7916
# Epoch 36/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3333 - accuracy: 0.8966 - precision: 0.9047 - recall: 0.9533 - binary cross entropy: 0.3279 - binary IoU: 0.7766
# Epoch 36: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0036.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3333 - accuracy: 0.8966 - precision: 0.9047 - recall: 0.9533 - binary cross entropy: 0.3279 - binary IoU: 0.7766
# Epoch 37/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3425 - accuracy: 0.8928 - precision: 0.9049 - recall: 0.9470 - binary cross entropy: 0.3372 - binary IoU: 0.7704
# Epoch 37: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0037.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3425 - accuracy: 0.8928 - precision: 0.9049 - recall: 0.9470 - binary cross entropy: 0.3371 - binary IoU: 0.7704
# Epoch 38/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3536 - accuracy: 0.8871 - precision: 0.9016 - recall: 0.9422 - binary cross entropy: 0.3474 - binary IoU: 0.7601
# Epoch 38: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0038.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3536 - accuracy: 0.8871 - precision: 0.9016 - recall: 0.9422 - binary cross entropy: 0.3474 - binary IoU: 0.7601
# Epoch 39/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8870 - precision: 0.9030 - recall: 0.9403 - binary cross entropy: 0.3470 - binary IoU: 0.7605
# Epoch 39: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0039.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3540 - accuracy: 0.8870 - precision: 0.9030 - recall: 0.9403 - binary cross entropy: 0.3470 - binary IoU: 0.7605
# Epoch 40/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3461 - accuracy: 0.8905 - precision: 0.9060 - recall: 0.9419 - binary cross entropy: 0.3399 - binary IoU: 0.7671
# Epoch 40: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0040.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3461 - accuracy: 0.8905 - precision: 0.9060 - recall: 0.9419 - binary cross entropy: 0.3399 - binary IoU: 0.7671
# Epoch 41/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3741 - accuracy: 0.8751 - precision: 0.8974 - recall: 0.9283 - binary cross entropy: 0.3656 - binary IoU: 0.7400
# Epoch 41: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0041.ckpt
# 25314/25314 [==============================] - 176s 7ms/step - loss: 0.3741 - accuracy: 0.8751 - precision: 0.8974 - recall: 0.9283 - binary cross entropy: 0.3656 - binary IoU: 0.7400
# Epoch 42/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3773 - accuracy: 0.8735 - precision: 0.8983 - recall: 0.9245 - binary cross entropy: 0.3685 - binary IoU: 0.7379
# Epoch 42: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0042.ckpt
# 25314/25314 [==============================] - 176s 7ms/step - loss: 0.3773 - accuracy: 0.8735 - precision: 0.8983 - recall: 0.9245 - binary cross entropy: 0.3686 - binary IoU: 0.7379
# Epoch 43/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3809 - accuracy: 0.8709 - precision: 0.8926 - recall: 0.9279 - binary cross entropy: 0.3739 - binary IoU: 0.7318
# Epoch 43: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0043.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3809 - accuracy: 0.8709 - precision: 0.8926 - recall: 0.9279 - binary cross entropy: 0.3739 - binary IoU: 0.7318
# Epoch 44/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3559 - accuracy: 0.8856 - precision: 0.8978 - recall: 0.9448 - binary cross entropy: 0.3495 - binary IoU: 0.7564
# Epoch 44: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0044.ckpt
# 25314/25314 [==============================] - 177s 7ms/step - loss: 0.3559 - accuracy: 0.8856 - precision: 0.8978 - recall: 0.9448 - binary cross entropy: 0.3495 - binary IoU: 0.7564
# Epoch 45/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3509 - accuracy: 0.8882 - precision: 0.9032 - recall: 0.9418 - binary cross entropy: 0.3443 - binary IoU: 0.7624
# Epoch 45: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0045.ckpt
# 25314/25314 [==============================] - 181s 7ms/step - loss: 0.3509 - accuracy: 0.8882 - precision: 0.9032 - recall: 0.9418 - binary cross entropy: 0.3443 - binary IoU: 0.7624
# Epoch 46/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8737 - precision: 0.8896 - recall: 0.9365 - binary cross entropy: 0.3697 - binary IoU: 0.7349
# Epoch 46: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0046.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3769 - accuracy: 0.8737 - precision: 0.8896 - recall: 0.9365 - binary cross entropy: 0.3697 - binary IoU: 0.7349
# Epoch 47/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3557 - accuracy: 0.8857 - precision: 0.9016 - recall: 0.9399 - binary cross entropy: 0.3495 - binary IoU: 0.7578
# Epoch 47: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0047.ckpt
# 25314/25314 [==============================] - 181s 7ms/step - loss: 0.3557 - accuracy: 0.8857 - precision: 0.9016 - recall: 0.9399 - binary cross entropy: 0.3495 - binary IoU: 0.7578
# Epoch 48/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3648 - accuracy: 0.8800 - precision: 0.9002 - recall: 0.9326 - binary cross entropy: 0.3598 - binary IoU: 0.7484
# Epoch 48: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0048.ckpt
# 25314/25314 [==============================] - 181s 7ms/step - loss: 0.3648 - accuracy: 0.8799 - precision: 0.9002 - recall: 0.9326 - binary cross entropy: 0.3598 - binary IoU: 0.7484
# Epoch 49/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8893 - precision: 0.9094 - recall: 0.9356 - binary cross entropy: 0.3419 - binary IoU: 0.7663
# Epoch 49: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0049.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3473 - accuracy: 0.8893 - precision: 0.9094 - recall: 0.9356 - binary cross entropy: 0.3419 - binary IoU: 0.7663
# Epoch 50/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3512 - accuracy: 0.8859 - precision: 0.9092 - recall: 0.9305 - binary cross entropy: 0.3472 - binary IoU: 0.7608
# Epoch 50: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0050.ckpt
# 25314/25314 [==============================] - 179s 7ms/step - loss: 0.3512 - accuracy: 0.8859 - precision: 0.9092 - recall: 0.9305 - binary cross entropy: 0.3472 - binary IoU: 0.7608
# Epoch 51/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3467 - accuracy: 0.8895 - precision: 0.9086 - recall: 0.9370 - binary cross entropy: 0.3423 - binary IoU: 0.7664
# Epoch 51: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0051.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3467 - accuracy: 0.8895 - precision: 0.9086 - recall: 0.9370 - binary cross entropy: 0.3423 - binary IoU: 0.7663
# Epoch 52/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3553 - accuracy: 0.8853 - precision: 0.9031 - recall: 0.9373 - binary cross entropy: 0.3503 - binary IoU: 0.7578
# Epoch 52: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0052.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3553 - accuracy: 0.8853 - precision: 0.9031 - recall: 0.9373 - binary cross entropy: 0.3503 - binary IoU: 0.7578
# Epoch 53/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3545 - accuracy: 0.8854 - precision: 0.9031 - recall: 0.9375 - binary cross entropy: 0.3505 - binary IoU: 0.7580
# Epoch 53: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0053.ckpt
# 25314/25314 [==============================] - 179s 7ms/step - loss: 0.3545 - accuracy: 0.8854 - precision: 0.9031 - recall: 0.9375 - binary cross entropy: 0.3505 - binary IoU: 0.7580
# Epoch 54/100
# 25307/25314 [============================>.] - ETA: 0s - loss: 0.3665 - accuracy: 0.8770 - precision: 0.9063 - recall: 0.9202 - binary cross entropy: 0.3628 - binary IoU: 0.7461
# Epoch 54: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0054.ckpt
# 25314/25314 [==============================] - 177s 7ms/step - loss: 0.3665 - accuracy: 0.8770 - precision: 0.9062 - recall: 0.9201 - binary cross entropy: 0.3628 - binary IoU: 0.7461
# Epoch 55/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3684 - accuracy: 0.8772 - precision: 0.9035 - recall: 0.9239 - binary cross entropy: 0.3636 - binary IoU: 0.7454
# Epoch 55: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0055.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3684 - accuracy: 0.8772 - precision: 0.9035 - recall: 0.9239 - binary cross entropy: 0.3636 - binary IoU: 0.7454
# Epoch 56/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3694 - accuracy: 0.8742 - precision: 0.9089 - recall: 0.9124 - binary cross entropy: 0.3654 - binary IoU: 0.7427
# Epoch 56: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0056.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3694 - accuracy: 0.8742 - precision: 0.9089 - recall: 0.9124 - binary cross entropy: 0.3654 - binary IoU: 0.7427
# Epoch 57/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3680 - accuracy: 0.8770 - precision: 0.9043 - recall: 0.9226 - binary cross entropy: 0.3635 - binary IoU: 0.7455
# Epoch 57: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0057.ckpt
# 25314/25314 [==============================] - 177s 7ms/step - loss: 0.3680 - accuracy: 0.8770 - precision: 0.9044 - recall: 0.9226 - binary cross entropy: 0.3635 - binary IoU: 0.7455
# Epoch 58/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3722 - accuracy: 0.8755 - precision: 0.9016 - recall: 0.9237 - binary cross entropy: 0.3670 - binary IoU: 0.7422
# Epoch 58: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0058.ckpt
# 25314/25314 [==============================] - 177s 7ms/step - loss: 0.3722 - accuracy: 0.8755 - precision: 0.9016 - recall: 0.9237 - binary cross entropy: 0.3670 - binary IoU: 0.7422
# Epoch 59/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8724 - precision: 0.9083 - recall: 0.9103 - binary cross entropy: 0.3682 - binary IoU: 0.7398
# Epoch 59: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0059.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3721 - accuracy: 0.8724 - precision: 0.9083 - recall: 0.9103 - binary cross entropy: 0.3682 - binary IoU: 0.7398
# Epoch 60/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3698 - accuracy: 0.8745 - precision: 0.9076 - recall: 0.9144 - binary cross entropy: 0.3659 - binary IoU: 0.7427
# Epoch 60: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0060.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3698 - accuracy: 0.8745 - precision: 0.9076 - recall: 0.9144 - binary cross entropy: 0.3659 - binary IoU: 0.7427
# Epoch 61/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3734 - accuracy: 0.8733 - precision: 0.9056 - recall: 0.9150 - binary cross entropy: 0.3691 - binary IoU: 0.7402
# Epoch 61: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0061.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3734 - accuracy: 0.8733 - precision: 0.9056 - recall: 0.9150 - binary cross entropy: 0.3691 - binary IoU: 0.7402
# Epoch 62/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8698 - precision: 0.8999 - recall: 0.9167 - binary cross entropy: 0.3759 - binary IoU: 0.7330
# Epoch 62: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0062.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3814 - accuracy: 0.8698 - precision: 0.8999 - recall: 0.9167 - binary cross entropy: 0.3759 - binary IoU: 0.7330
# Epoch 63/100
# 25313/25314 [============================>.] - ETA: 0s - loss: 0.3669 - accuracy: 0.8780 - precision: 0.9077 - recall: 0.9199 - binary cross entropy: 0.3604 - binary IoU: 0.7481
# Epoch 63: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0063.ckpt
# 25314/25314 [==============================] - 176s 7ms/step - loss: 0.3669 - accuracy: 0.8780 - precision: 0.9077 - recall: 0.9199 - binary cross entropy: 0.3604 - binary IoU: 0.7481
# Epoch 64/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3612 - accuracy: 0.8803 - precision: 0.9093 - recall: 0.9215 - binary cross entropy: 0.3564 - binary IoU: 0.7521
# Epoch 64: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0064.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3612 - accuracy: 0.8803 - precision: 0.9093 - recall: 0.9215 - binary cross entropy: 0.3564 - binary IoU: 0.7521
# Epoch 65/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3649 - accuracy: 0.8781 - precision: 0.9093 - recall: 0.9181 - binary cross entropy: 0.3601 - binary IoU: 0.7488
# Epoch 65: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0065.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3649 - accuracy: 0.8781 - precision: 0.9093 - recall: 0.9181 - binary cross entropy: 0.3601 - binary IoU: 0.7488
# Epoch 66/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3707 - accuracy: 0.8735 - precision: 0.9094 - recall: 0.9107 - binary cross entropy: 0.3662 - binary IoU: 0.7418
# Epoch 66: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0066.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3707 - accuracy: 0.8735 - precision: 0.9094 - recall: 0.9107 - binary cross entropy: 0.3662 - binary IoU: 0.7418
# Epoch 67/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3655 - accuracy: 0.8775 - precision: 0.9089 - recall: 0.9176 - binary cross entropy: 0.3611 - binary IoU: 0.7477
# Epoch 67: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0067.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3655 - accuracy: 0.8775 - precision: 0.9089 - recall: 0.9176 - binary cross entropy: 0.3611 - binary IoU: 0.7477
# Epoch 68/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3697 - accuracy: 0.8761 - precision: 0.9046 - recall: 0.9209 - binary cross entropy: 0.3648 - binary IoU: 0.7441
# Epoch 68: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0068.ckpt
# 25314/25314 [==============================] - 175s 7ms/step - loss: 0.3697 - accuracy: 0.8761 - precision: 0.9046 - recall: 0.9209 - binary cross entropy: 0.3648 - binary IoU: 0.7441
# Epoch 69/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8738 - precision: 0.9054 - recall: 0.9162 - binary cross entropy: 0.3673 - binary IoU: 0.7409
# Epoch 69: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0069.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3720 - accuracy: 0.8738 - precision: 0.9054 - recall: 0.9162 - binary cross entropy: 0.3673 - binary IoU: 0.7409
# Epoch 70/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.8724 - precision: 0.9016 - recall: 0.9187 - binary cross entropy: 0.3712 - binary IoU: 0.7375
# Epoch 70: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0070.ckpt
# 25314/25314 [==============================] - 185s 7ms/step - loss: 0.3762 - accuracy: 0.8724 - precision: 0.9016 - recall: 0.9187 - binary cross entropy: 0.3712 - binary IoU: 0.7375
# Epoch 71/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8744 - precision: 0.9014 - recall: 0.9222 - binary cross entropy: 0.3684 - binary IoU: 0.7405
# Epoch 71: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0071.ckpt
# 25314/25314 [==============================] - 179s 7ms/step - loss: 0.3737 - accuracy: 0.8744 - precision: 0.9014 - recall: 0.9222 - binary cross entropy: 0.3684 - binary IoU: 0.7405
# Epoch 72/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8776 - precision: 0.9011 - recall: 0.9276 - binary cross entropy: 0.3643 - binary IoU: 0.7452
# Epoch 72: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0072.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3696 - accuracy: 0.8776 - precision: 0.9011 - recall: 0.9276 - binary cross entropy: 0.3643 - binary IoU: 0.7452
# Epoch 73/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3769 - accuracy: 0.8740 - precision: 0.8980 - recall: 0.9259 - binary cross entropy: 0.3708 - binary IoU: 0.7385
# Epoch 73: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0073.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3769 - accuracy: 0.8740 - precision: 0.8980 - recall: 0.9259 - binary cross entropy: 0.3708 - binary IoU: 0.7385
# Epoch 74/100
# 25310/25314 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8763 - precision: 0.8982 - recall: 0.9293 - binary cross entropy: 0.3661 - binary IoU: 0.7421
# Epoch 74: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0074.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3706 - accuracy: 0.8763 - precision: 0.8982 - recall: 0.9293 - binary cross entropy: 0.3661 - binary IoU: 0.7421
# Epoch 75/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8675 - precision: 0.9025 - recall: 0.9097 - binary cross entropy: 0.3782 - binary IoU: 0.7305
# Epoch 75: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0075.ckpt
# 25314/25314 [==============================] - 180s 7ms/step - loss: 0.3823 - accuracy: 0.8675 - precision: 0.9025 - recall: 0.9097 - binary cross entropy: 0.3782 - binary IoU: 0.7305
# Epoch 76/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3756 - accuracy: 0.8705 - precision: 0.9070 - recall: 0.9089 - binary cross entropy: 0.3715 - binary IoU: 0.7365
# Epoch 76: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0076.ckpt
# 25314/25314 [==============================] - 181s 7ms/step - loss: 0.3756 - accuracy: 0.8705 - precision: 0.9070 - recall: 0.9089 - binary cross entropy: 0.3715 - binary IoU: 0.7365
# Epoch 77/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3812 - accuracy: 0.8686 - precision: 0.9022 - recall: 0.9120 - binary cross entropy: 0.3769 - binary IoU: 0.7321
# Epoch 77: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0077.ckpt
# 25314/25314 [==============================] - 178s 7ms/step - loss: 0.3811 - accuracy: 0.8687 - precision: 0.9022 - recall: 0.9120 - binary cross entropy: 0.3769 - binary IoU: 0.7321
# Epoch 78/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3790 - accuracy: 0.8689 - precision: 0.9057 - recall: 0.9080 - binary cross entropy: 0.3751 - binary IoU: 0.7337
# Epoch 78: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0078.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3790 - accuracy: 0.8689 - precision: 0.9057 - recall: 0.9080 - binary cross entropy: 0.3751 - binary IoU: 0.7337
# Epoch 79/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3874 - accuracy: 0.8669 - precision: 0.8939 - recall: 0.9198 - binary cross entropy: 0.3836 - binary IoU: 0.7265
# Epoch 79: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0079.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3874 - accuracy: 0.8669 - precision: 0.8939 - recall: 0.9198 - binary cross entropy: 0.3836 - binary IoU: 0.7265
# Epoch 80/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8706 - precision: 0.9022 - recall: 0.9150 - binary cross entropy: 0.3747 - binary IoU: 0.7350
# Epoch 80: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0080.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3791 - accuracy: 0.8706 - precision: 0.9022 - recall: 0.9150 - binary cross entropy: 0.3747 - binary IoU: 0.7350
# Epoch 81/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3823 - accuracy: 0.8679 - precision: 0.9020 - recall: 0.9110 - binary cross entropy: 0.3784 - binary IoU: 0.7310
# Epoch 81: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0081.ckpt
# 25314/25314 [==============================] - 172s 7ms/step - loss: 0.3823 - accuracy: 0.8679 - precision: 0.9020 - recall: 0.9110 - binary cross entropy: 0.3784 - binary IoU: 0.7310
# Epoch 82/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3804 - accuracy: 0.8668 - precision: 0.9067 - recall: 0.9033 - binary cross entropy: 0.3767 - binary IoU: 0.7309
# Epoch 82: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0082.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3804 - accuracy: 0.8668 - precision: 0.9067 - recall: 0.9033 - binary cross entropy: 0.3767 - binary IoU: 0.7309
# Epoch 83/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3785 - accuracy: 0.8680 - precision: 0.9079 - recall: 0.9038 - binary cross entropy: 0.3742 - binary IoU: 0.7330
# Epoch 83: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0083.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3785 - accuracy: 0.8680 - precision: 0.9079 - recall: 0.9038 - binary cross entropy: 0.3742 - binary IoU: 0.7331
# Epoch 84/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3807 - accuracy: 0.8676 - precision: 0.9060 - recall: 0.9056 - binary cross entropy: 0.3767 - binary IoU: 0.7319
# Epoch 84: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0084.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3807 - accuracy: 0.8676 - precision: 0.9060 - recall: 0.9056 - binary cross entropy: 0.3767 - binary IoU: 0.7319
# Epoch 85/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3841 - accuracy: 0.8638 - precision: 0.9078 - recall: 0.8972 - binary cross entropy: 0.3802 - binary IoU: 0.7268
# Epoch 85: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0085.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3841 - accuracy: 0.8638 - precision: 0.9078 - recall: 0.8972 - binary cross entropy: 0.3802 - binary IoU: 0.7268
# Epoch 86/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3745 - accuracy: 0.8708 - precision: 0.9092 - recall: 0.9067 - binary cross entropy: 0.3703 - binary IoU: 0.7377
# Epoch 86: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0086.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3744 - accuracy: 0.8708 - precision: 0.9092 - recall: 0.9067 - binary cross entropy: 0.3703 - binary IoU: 0.7378
# Epoch 87/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3715 - accuracy: 0.8723 - precision: 0.9090 - recall: 0.9093 - binary cross entropy: 0.3685 - binary IoU: 0.7399
# Epoch 87: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0087.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3715 - accuracy: 0.8723 - precision: 0.9090 - recall: 0.9093 - binary cross entropy: 0.3685 - binary IoU: 0.7399
# Epoch 88/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3790 - accuracy: 0.8662 - precision: 0.9102 - recall: 0.8982 - binary cross entropy: 0.3758 - binary IoU: 0.7311
# Epoch 88: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0088.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3790 - accuracy: 0.8662 - precision: 0.9102 - recall: 0.8982 - binary cross entropy: 0.3758 - binary IoU: 0.7311
# Epoch 89/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3826 - accuracy: 0.8650 - precision: 0.9081 - recall: 0.8988 - binary cross entropy: 0.3787 - binary IoU: 0.7287
# Epoch 89: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0089.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3826 - accuracy: 0.8650 - precision: 0.9081 - recall: 0.8988 - binary cross entropy: 0.3787 - binary IoU: 0.7287
# Epoch 90/100
# 25314/25314 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8645 - precision: 0.9058 - recall: 0.9008 - binary cross entropy: 0.3804 - binary IoU: 0.7272
# Epoch 90: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0090.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3854 - accuracy: 0.8645 - precision: 0.9058 - recall: 0.9008 - binary cross entropy: 0.3804 - binary IoU: 0.7272
# Epoch 91/100
# 25307/25314 [============================>.] - ETA: 0s - loss: 0.3847 - accuracy: 0.8666 - precision: 0.9024 - recall: 0.9085 - binary cross entropy: 0.3790 - binary IoU: 0.7292
# Epoch 91: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0091.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3847 - accuracy: 0.8666 - precision: 0.9024 - recall: 0.9085 - binary cross entropy: 0.3790 - binary IoU: 0.7292
# Epoch 92/100
# 25309/25314 [============================>.] - ETA: 0s - loss: 0.3811 - accuracy: 0.8667 - precision: 0.9079 - recall: 0.9018 - binary cross entropy: 0.3768 - binary IoU: 0.7312
# Epoch 92: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0092.ckpt
# 25314/25314 [==============================] - 174s 7ms/step - loss: 0.3811 - accuracy: 0.8667 - precision: 0.9079 - recall: 0.9018 - binary cross entropy: 0.3768 - binary IoU: 0.7311
# Epoch 93/100
# 25308/25314 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8699 - precision: 0.9081 - recall: 0.9066 - binary cross entropy: 0.3724 - binary IoU: 0.7359
# Epoch 93: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0093.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3770 - accuracy: 0.8699 - precision: 0.9081 - recall: 0.9066 - binary cross entropy: 0.3724 - binary IoU: 0.7360
# Epoch 94/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3846 - accuracy: 0.8637 - precision: 0.9085 - recall: 0.8964 - binary cross entropy: 0.3804 - binary IoU: 0.7270
# Epoch 94: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0094.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3846 - accuracy: 0.8637 - precision: 0.9085 - recall: 0.8964 - binary cross entropy: 0.3804 - binary IoU: 0.7270
# Epoch 95/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.8610 - precision: 0.9060 - recall: 0.8951 - binary cross entropy: 0.3845 - binary IoU: 0.7222
# Epoch 95: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0095.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3885 - accuracy: 0.8610 - precision: 0.9060 - recall: 0.8951 - binary cross entropy: 0.3845 - binary IoU: 0.7222
# Epoch 96/100
# 25311/25314 [============================>.] - ETA: 0s - loss: 0.3857 - accuracy: 0.8634 - precision: 0.9073 - recall: 0.8973 - binary cross entropy: 0.3813 - binary IoU: 0.7262
# Epoch 96: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0096.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3857 - accuracy: 0.8634 - precision: 0.9073 - recall: 0.8973 - binary cross entropy: 0.3813 - binary IoU: 0.7262
# Epoch 97/100
# 25312/25314 [============================>.] - ETA: 0s - loss: 0.3865 - accuracy: 0.8633 - precision: 0.9046 - recall: 0.9004 - binary cross entropy: 0.3832 - binary IoU: 0.7251
# Epoch 97: saving model to /MSC_THESIS/MyDrive/School - Ryerson Graduate/MSC_THESIS/logs/23Jul09_Regularized_LSTM/cp-0097.ckpt
# 25314/25314 [==============================] - 173s 7ms/step - loss: 0.3865 - accuracy: 0.8633 - precision: 0.9046 - recall: 0.9004 - binary cross entropy: 0.3832 - binary IoU: 0.7251
# Epoch 98/100
# 20963/25314 [=======================>......] - ETA: 29s - loss: 0.3915 - accuracy: 0.8589 - precision: 0.9065 - recall: 0.8911 - binary cross entropy: 0.3875 - binary IoU: 0.7193
